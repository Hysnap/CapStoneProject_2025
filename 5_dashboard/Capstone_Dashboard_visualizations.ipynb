# %% [markdown]
# # **Paul Golder - Capstone Project March 2025**

# %% [markdown]
# ## Objectives
#
# * This notebook is a scratch pad for code to be used to create visualizations in either python or using python in powerbi
#
# ## Inputs
#
# * files from the ETL and ML_Model_Chatgpt_refactor files
#
# ## Outputs
#
# * Code or images for inclusion in the dashboard.
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'h:\\VScode\\CapStoneProject_2025-1\\5_dashboard'

# %%
# check current directory contains the file README.md
if os.path.exists("README.md"):
    print("The file README.md exists in the current directory")
else:
    print("The file README.md does not exist in the current directory")
    print("You are in the directory: ", current_dir)
    print("Changing current directory to its parent directory")
    os.chdir(os.path.dirname(current_dir))
    print("You set a new current directory")
    current_dir = os.getcwd()
    if os.path.exists("README.md"):
        print("The file README.md exists in the current directory")
    else:
        RuntimeError("The file README.md does not exist in the current directory, please check the current directory")
        print("Current Directory =", current_dir)
# Out:
# The file README.md does not exist in the current directory
# You are in the directory:  h:\VScode\CapStoneProject_2025-1\5_dashboard
# Changing current directory to its parent directory
# You set a new current directory
# The file README.md exists in the current directory

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the combined_data.zip file
df = pd.read_csv("data//combined_data.zip", compression='zip')
print("The shape of the data is: ", df.shape)
df.head()
# Out:
# The shape of the data is:  (44013, 44)
#    index                                              title       subject  \
# 0      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
# 1      1  U.S. military to accept transgender recruits o...  politicsNews
# 2      2  Senior U.S. Republican senator: 'Let Mr. Muell...  politicsNews
# 3      3  FBI Russia probe helped by Australian diplomat...  politicsNews
# 4      4  Trump wants Postal Service to charge 'much mor...  politicsNews
#
#    label  Column1  subject2 media_type  month  day  year  ...  \
# 0      1      NaN       NaN  instagram     12   31  2017  ...
# 1      1      NaN       NaN    twitter     12   29  2017  ...
# 2      1      NaN       NaN    twitter     12   31  2017  ...
# 3      1      NaN       NaN   facebook     12   30  2017  ...
# 4      1      NaN       NaN      video     12   29  2017  ...
#
#   overall_polarity overall_subjectivity  contradiction_polarity  \
# 0         0.013835             0.205609                0.027671
# 1        -0.002733             0.201324                0.194533
# 2         0.063582             0.159538                0.127165
# 3         0.015749             0.131303                0.031498
# 4         0.114085             0.278986               -0.171830
#
#    contradiction_subjectivity  polarity_variations  subjectivity_variations  \
# 0                    0.411218             0.000000                 0.000000
# 1                    0.202647            -1.945332                 2.026472
# 2                    0.319076             0.000000                 0.000000
# 3                    0.262607             0.000000                 0.000000
# 4                    0.157971            -0.859149                 0.789855
#
#     sentiment_article           sentiment_title         sentiment_overall  \
# 0    positive neutral   neutral higly objective        positive objective
# 1  positive objective  negative higly objective        negative objective
# 2  positive objective   neutral higly objective  positive higly objective
# 3  positive objective   neutral higly objective  positive higly objective
# 4  positive objective  positive higly objective        positive objective
#
#                                 locationsfromarticle
# 0  ['washington', 'florida', 'florida', 'texas', ...
# 1  ['washington', 'virginia', 'seattle', 'califor...
# 2  ['russia', 'russia', 'russia', 'new york', 'ru...
# 3  ['russia', 'new york', 'london', 'moscow', 'ru...
# 4                       ['washington', 'washington']
#
# [5 rows x 44 columns]

# %%
# load location data from the unique_locations.csv file
locations = pd.read_csv("data//unique_locations.csv")
print(locations.info())
locations.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4896 entries, 0 to 4895
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             4896 non-null   int64
#  1   location          4895 non-null   object
#  2   geolocation_info  2744 non-null   object
#  3   latitude          2744 non-null   float64
#  4   longitude         2744 non-null   float64
#  5   address           2744 non-null   object
#  6   continent         1295 non-null   object
#  7   country           2744 non-null   object
#  8   state             2011 non-null   object
#  9   ignore            4896 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 382.6+ KB
# None
#    index          location                                   geolocation_info  \
# 0   2831     south georgia  {'latitude': -54.4138333, 'longitude': -36.582...
# 1   1313       white beach  {'latitude': -43.1243919, 'longitude': 147.721...
# 2    920       west plenty  {'latitude': -42.8883088, 'longitude': 146.859...
# 3   4364  patagonia region  {'latitude': -41.8101472, 'longitude': -68.906...
# 4    593        wellington  {'latitude': -41.2923814, 'longitude': 174.778...
#
#     latitude   longitude                                            address  \
# 0 -54.413833  -36.582716  South Georgia Island, SIQQ 1ZZ, South Georgia ...
# 1 -43.124392  147.721933                    White Beach TAS 7184, Australia
# 2 -42.888309  146.859902              W Plenty Rd, Tasmania 7140, Australia
# 3 -41.810147  -68.906269                                          Patagonia
# 4 -41.292381  174.778746                            Wellington, New Zealand
#
#               continent                                       country  \
# 0  South Georgia Island  South Georgia and the South Sandwich Islands
# 1                   NaN                                     Australia
# 2           W Plenty Rd                                     Australia
# 3                   NaN                                     Patagonia
# 4                   NaN                                   New Zealand
#
#                   state  ignore
# 0              SIQQ 1ZZ       0
# 1  White Beach TAS 7184       0
# 2         Tasmania 7140       0
# 3                   NaN       0
# 4            Wellington       0

# %%
# load locationsfromarticle.zip file
locationsfromarticle = pd.read_csv("data//locationsfromarticle.zip", compression='zip')
print(locationsfromarticle.info())
locationsfromarticle.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217999 entries, 0 to 217998
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   index       217999 non-null  int64
#  1   article_id  217999 non-null  int64
#  2   location    210129 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 5.0+ MB
# None
#    index  article_id    location
# 0      0           0  washington
# 1      0           0     florida
# 2      0           0     florida
# 3      0           0       texas
# 4      0           0  california

# %%
# match locations to locationsfromarticle
locations['location'] = locations['location'].str.lower()
locationsfromarticle['location'] = locationsfromarticle['location'].str.lower()
locationsmerged = locations.merge(locationsfromarticle, on='location', how='left')
print(locationsmerged.info())
locationsmerged.head()

del locations, locationsfromarticle
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217999 entries, 0 to 217998
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index_x           217999 non-null  int64
#  1   location          210129 non-null  object
#  2   geolocation_info  203080 non-null  object
#  3   latitude          203080 non-null  float64
#  4   longitude         203080 non-null  float64
#  5   address           203080 non-null  object
#  6   continent         42977 non-null   object
#  7   country           203080 non-null  object
#  8   state             95391 non-null   object
#  9   ignore            217999 non-null  int64
#  10  index_y           217999 non-null  int64
#  11  article_id        217999 non-null  int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 20.0+ MB
# None

# %%
# drop all rows with ignore = 1
locationsmerged = locationsmerged[locationsmerged['ignore'] != 1]
locationsmerged = locationsmerged.drop(columns=['ignore'])
locationsmerged.head()
locationsmerged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 203080 entries, 0 to 203079
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index_x           203080 non-null  int64
#  1   location          203080 non-null  object
#  2   geolocation_info  203080 non-null  object
#  3   latitude          203080 non-null  float64
#  4   longitude         203080 non-null  float64
#  5   address           203080 non-null  object
#  6   continent         42977 non-null   object
#  7   country           203080 non-null  object
#  8   state             95391 non-null   object
#  9   index_y           203080 non-null  int64
#  10  article_id        203080 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 18.6+ MB

# %%
# merge locationsmerged with df
locationgraphdf = df.merge(locationsmerged, on='article_id', how='left')
print(locationgraphdf.info())
locationgraphdf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204162 entries, 0 to 204161
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   index                       204162 non-null  int64
#  1   title                       204162 non-null  object
#  2   subject                     204162 non-null  object
#  3   label                       204162 non-null  int64
#  4   Column1                     0 non-null       float64
#  5   subject2                    0 non-null       float64
#  6   media_type                  204162 non-null  object
#  7   month                       204162 non-null  int64
#  8   day                         204162 non-null  int64
#  9   year                        204162 non-null  int64
#  10  date_clean                  204162 non-null  object
#  11  day_of_week                 204162 non-null  object
#  12  week_of_year                204162 non-null  int64
#  13  is_weekend                  204162 non-null  int64
#  14  is_weekday                  204162 non-null  int64
#  15  week_of_year_sin            204162 non-null  float64
#  16  week_of_year_cos            204162 non-null  float64
#  17  holiday                     204162 non-null  int64
#  18  day_of_month_sine           204162 non-null  float64
#  19  day_of_month_cos            204162 non-null  float64
#  20  month_sin                   204162 non-null  float64
#  21  month_cos                   204162 non-null  float64
#  22  day_label                   204162 non-null  object
#  23  article_id                  204162 non-null  int64
#  24  cleaned_text                204162 non-null  object
#  25  source_name                 204162 non-null  object
#  26  title_length                204162 non-null  int64
#  27  text_length                 204162 non-null  int64
#  28  nlp_text                    204159 non-null  object
#  29  nlp_title                   204162 non-null  object
#  30  article_polarity            204162 non-null  float64
#  31  article_subjectivity        204162 non-null  float64
#  32  title_polarity              204162 non-null  float64
#  33  title_subjectivity          204162 non-null  float64
#  34  overall_polarity            204162 non-null  float64
#  35  overall_subjectivity        204162 non-null  float64
#  36  contradiction_polarity      204162 non-null  float64
#  37  contradiction_subjectivity  204162 non-null  float64
#  38  polarity_variations         204162 non-null  float64
#  39  subjectivity_variations     204162 non-null  float64
#  40  sentiment_article           204162 non-null  object
#  41  sentiment_title             204162 non-null  object
#  42  sentiment_overall           204162 non-null  object
#  43  locationsfromarticle        204162 non-null  object
#  44  index_x                     195836 non-null  float64
#  45  location                    195836 non-null  object
#  46  geolocation_info            195836 non-null  object
#  47  latitude                    195836 non-null  float64
#  48  longitude                   195836 non-null  float64
#  49  address                     195836 non-null  object
#  50  continent                   41266 non-null   object
#  51  country                     195836 non-null  object
#  52  state                       92582 non-null   object
#  53  index_y                     195836 non-null  float64
# dtypes: float64(22), int64(12), object(20)
# memory usage: 84.1+ MB
# None
#    index                                              title       subject  \
# 0      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
# 1      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
# 2      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
# 3      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
# 4      0  As U.S. budget fight looms, Republicans flip t...  politicsNews
#
#    label  Column1  subject2 media_type  month  day  year  ... index_x  \
# 0      1      NaN       NaN  instagram     12   31  2017  ...     1.0
# 1      1      NaN       NaN  instagram     12   31  2017  ...     1.0
# 2      1      NaN       NaN  instagram     12   31  2017  ...     2.0
# 3      1      NaN       NaN  instagram     12   31  2017  ...     3.0
# 4      1      NaN       NaN  instagram     12   31  2017  ...     0.0
#
#      location                                   geolocation_info   latitude  \
# 0     florida  {'latitude': 27.6648274, 'longitude': -81.5157...  27.664827
# 1     florida  {'latitude': 27.6648274, 'longitude': -81.5157...  27.664827
# 2       texas  {'latitude': 31.9685988, 'longitude': -99.9018...  31.968599
# 3  california  {'latitude': 36.778261, 'longitude': -119.4179...  36.778261
# 4  washington  {'latitude': 38.9071923, 'longitude': -77.0368...  38.907192
#
#     longitude              address   continent  country       state  index_y
# 0  -81.515754         Florida, USA         NaN      USA     Florida      0.0
# 1  -81.515754         Florida, USA         NaN      USA     Florida      0.0
# 2  -99.901813           Texas, USA         NaN      USA       Texas      0.0
# 3 -119.417932      California, USA         NaN      USA  California      0.0
# 4  -77.036871  Washington, DC, USA  Washington      USA          DC      0.0
#
# [5 rows x 54 columns]

# %%
# using plotly create a map that displays the number of fake articles, real articles, and total articles per country
import plotly.express as px
import plotly.graph_objects as go

# create a new dataframe with the number of fake articles per country
fakearticles = locationgraphdf[locationgraphdf['label'] == 1]
fakearticles = fakearticles.groupby(['year', 'month', 'country']).size().reset_index(name='fake_count')

# create a new dataframe with the number of real articles per country
realarticles = locationgraphdf[locationgraphdf['label'] == 0]
realarticles = realarticles.groupby(['year', 'month', 'country']).size().reset_index(name='real_count')

# merge fake and real articles dataframes
articles = pd.merge(fakearticles, realarticles, on=['year', 'month', 'country'], how='outer').fillna(0)
articles = articles.sort_values(by=['year', 'month', 'country'])
articles.head()

# create a map that displays the number of fake articles and real articles per country

fig = go.Figure()

# Add a slider to filter by month and year
years = articles['year'].unique()
months = articles['month'].unique()

for year in years:
    for month in months:
        filtered_data = articles[(articles['year'] == year) & (articles['month'] == month)]
        fig.add_trace(go.Choropleth(
            visible=False,
            locations=filtered_data['country'],
            z=filtered_data['fake_count'],
            locationmode='country names',
            colorscale='Reds',
            colorbar_title="Number of Fake Articles",
            text=filtered_data[['fake_count', 'real_count']],
            hovertemplate='<b>%{location}</b><br>Fake Articles: %{z}<br>Real Articles: %{text[1]}',
            name=f'{year}-{month} (Fake)'
        ))
        fig.add_trace(go.Choropleth(
            visible=False,
            locations=filtered_data['country'],
            z=filtered_data['real_count'],
            locationmode='country names',
            colorscale='Blues',
            colorbar_title="Number of Real Articles",
            text=filtered_data[['fake_count', 'real_count']],
            hovertemplate='<b>%{location}</b><br>Fake Articles: %{text[0]}<br>Real Articles: %{z}',
            name=f'{year}-{month} (Real)'
        ))

# Make the first trace visible
fig.data[0].visible = True

# Create and add slider
steps = []
for i in range(0, len(fig.data), 2):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(fig.data)},
              {"title": f"Articles per Country - {fig.data[i].name.split(' ')[0]}"}],
        label=fig.data[i].name.split(' ')[0]  # Add label here
    )
    step["args"][0]["visible"][i:i+2] = [True, True]
    steps.append(step)

sliders = [dict(
    active=0,
    currentvalue={"prefix": "Date: "},
    pad={"t": 50},
    steps=steps
)]

# Add filter buttons
button_layer_1_height = 1.12
fig.update_layout(
    sliders=sliders,
    title_text='Articles per Country',
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'
    ),
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["visible", [True if "Fake" in trace.name else False for trace in fig.data]],
                    label="Fake Articles",
                    method="restyle"
                ),
                dict(
                    args=["visible", [True if "Real" in trace.name else False for trace in fig.data]],
                    label="Real Articles",
                    method="restyle"
                ),
                dict(
                    args=["visible", [True] * len(fig.data)],
                    label="All",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.17,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
        ),
    ]
)

fig.show()

# %% [markdown]
# ---
